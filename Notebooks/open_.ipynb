# %%
import pandas as pd

# %%
df = pd.read_csv('distribution_Pleuro_ACDC.csv', sep="\t",  header=1)

# %%
from transformers import TapexTokenizer

# %%
tokenizer = TapexTokenizer.from_pretrained('microsoft/tapex-large')
# Out:
# tokenizer_config.json:   0%|          | 0.00/1.17k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/899k [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]

# %%
df = df.astype(str)

# %%
tokens = tokenizer(df, return_tensors="pt")
# Out:
# Token indices sequence length is longer than the specified maximum sequence length for this model (422801 > 1024). Running this sequence through the model will result in indexing errors

# %%
(tokens["input_ids"]).size(
)
# Out:
# torch.Size([1, 422801])

# %%
422801/1024
# Out:
# 412.8916015625
